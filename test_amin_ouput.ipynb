# %%
# %load_ext autoreload
# %autoreload 2

# %%
base_path = '/run/user/1001/gvfs/smb-share:server=fs.ista.ac.at,share=drives/tnegrell/archive/siegegrp/AlVe/MORPHOMICS2.0_MICROGLIA_BRAIN_ATLAS/trial'

# %%
import numpy as np

# Load the .npz file
data = np.load(base_path+'/32.npz')

# List the contents of the .npz file (keys for each array)
print(data.__dict__.keys())

# Access a specific array by key (assuming the array is stored under the key 'arr_0')
array = data['arr_0']  # Replace 'arr_0' with the correct key
# Out:
# dict_keys(['_files', 'files', 'allow_pickle', 'max_header_size', 'pickle_kwargs', 'zip', 'f', 'fid'])

# %%
import matplotlib.pyplot as plt

# Assuming your 3D array is named `data`

# Plot multiple slices
fig, axes = plt.subplots(4, 4, figsize=(10, 10))  # 4x4 grid for 16 slices
for i, ax in enumerate(axes.flat):
    ax.imshow(array[:, :, i], cmap='gray')  # Display each slice
    ax.set_title(f"Slice {i}")
    ax.axis('off')

plt.tight_layout()
plt.show()
